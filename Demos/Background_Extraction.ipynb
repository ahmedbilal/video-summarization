# %%
import os
import sys
from matplotlib import pyplot as plt

# %%
sys.path.append(os.path.dirname(os.getcwd()))
from utils import ABKVideoCapture

# %%
video = ABKVideoCapture("wales_shortened_1min.m4v")

background = video.get_background()
plt.imshow(background)
plt.show()
